# %%
import matplotlib.pyplot as pltimport numpy as np# 设置中文字体plt.rcParams['font.sans-serif'] = ['Arial Unicode MS', 'SimHei', 'DejaVu Sans']plt.rcParams['axes.unicode_minus'] = False# 生成示例数据x = np.arange(1, 11)y1 = [2, 4, 5, 8, 7, 9, 12, 11, 14, 16]y2 = [1, 3, 6, 5, 9, 8, 10, 13, 12, 15]# 创建折线图plt.figure(figsize=(10, 6))plt.plot(x, y1, marker='o', linewidth=2, label='产品 A', color='#3498db')plt.plot(x, y2, marker='s', linewidth=2, label='产品 B', color='#e74c3c')# 添加标题和标签plt.title('月度销售趋势图', fontsize=16, fontweight='bold')plt.xlabel('月份', fontsize=12)plt.ylabel('销售额 (万元)', fontsize=12)# 添加网格和图例plt.grid(True, linestyle='--', alpha=0.7)plt.legend(fontsize=11)# 设置 x 轴刻度plt.xticks(x, [f'{i}月' for i in x])plt.tight_layout()plt.show()
# Out:
# <plot: /Users/lianghaoyun/project/nanobot/workspace/notebooks/default/plot_0.png>
# 📊 Generated 1 chart(s)  Chart 1: /Users/lianghaoyun/project/nanobot/workspace/notebooks/default/plot_0.png

# %% [markdown]
# ---
# *Executed at: 2026-03-30T14:05:49.154689*

# %%
import matplotlib.pyplot as pltimport numpy as np# 设置中文字体plt.rcParams['font.sans-serif'] = ['SimHei', 'DejaVu Sans']plt.rcParams['axes.unicode_minus'] = False# 生成数据x = np.arange(1, 11)y1 = np.random.randint(20, 80, size=10)y2 = np.random.randint(30, 90, size=10)# 创建图表plt.figure(figsize=(10, 6))plt.plot(x, y1, marker='o', linewidth=2, label='产品线 A', color='#3498db')plt.plot(x, y2, marker='s', linewidth=2, label='产品线 B', color='#e74c3c')# 添加标题和标签plt.title('月度销售趋势图', fontsize=16, fontweight='bold')plt.xlabel('月份', fontsize=12)plt.ylabel('销售额 (万元)', fontsize=12)# 添加图例plt.legend(loc='upper left', fontsize=10)# 添加网格plt.grid(True, linestyle='--', alpha=0.7)# 设置x轴刻度plt.xticks(x, ['1月', '2月', '3月', '4月', '5月', '6月', '7月', '8月', '9月', '10月'])# 在数据点上标注数值for i, (v1, v2) in enumerate(zip(y1, y2)):    plt.annotate(str(v1), (x[i], v1), textcoords="offset points", xytext=(0,10), ha='center', fontsize=8, color='#3498db')    plt.annotate(str(v2), (x[i], v2), textcoords="offset points", xytext=(0,-15), ha='center', fontsize=8, color='#e74c3c')plt.tight_layout()plt.show()
# Out:
# <plot: /Users/lianghaoyun/project/nanobot/workspace/notebooks/default/plot_0.png>
# ...

# %% [markdown]
# ---
# *Executed at: 2026-03-30T14:12:38.634779*

# %%
import matplotlib.pyplot as pltimport numpy as np# Generate sample datanp.random.seed(42)months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct']product_a = np.random.randint(30, 90, size=10)product_b = np.random.randint(25, 85, size=10)# Create figurefig, ax = plt.subplots(figsize=(10, 6))# Plot linesax.plot(months, product_a, marker='o', linewidth=2.5, markersize=8,         label='Product Line A', color='#3498db', markerfacecolor='white', markeredgewidth=2)ax.plot(months, product_b, marker='s', linewidth=2.5, markersize=8,         label='Product Line B', color='#e74c3c', markerfacecolor='white', markeredgewidth=2)# Stylingax.set_title('Monthly Sales Trend', fontsize=16, fontweight='bold', pad=15)ax.set_xlabel('Month', fontsize=12)ax.set_ylabel('Sales (10k)', fontsize=12)ax.legend(loc='upper left', fontsize=10, framealpha=0.9)ax.grid(True, linestyle='--', alpha=0.4)# Add value annotationsfor i, (a, b) in enumerate(zip(product_a, product_b)):    ax.annotate(f'{a}', (months[i], a), textcoords="offset points",                 xytext=(0, 10), ha='center', fontsize=9, color='#3498db', fontweight='bold')    ax.annotate(f'{b}', (months[i], b), textcoords="offset points",                 xytext=(0, -15), ha='center', fontsize=9, color='#e74c3c', fontweight='bold')# Fill area under linesax.fill_between(months, product_a, alpha=0.1, color='#3498db')ax.fill_between(months, product_b, alpha=0.1, color='#e74c3c')plt.tight_layout()plt.show()print(f"Data: Product A = {product_a.tolist()}")print(f"Data: Product B = {product_b.tolist()}")
# Out:
# <plot: /Users/lianghaoyun/project/nanobot/workspace/notebooks/default/plot_0.png>
# Data: Product A = [68, 81, 58, 44, 72, 37, 50, 68, 87, 48]Data: Product B = [47, 35, 35, 48, 77, 60, 64, 48, 27, 46]📊 Generated 1 chart(s)  Chart 1: /Users/lianghaoyun/project/nanobot/workspace/notebooks/default/plot_0.png

# %% [markdown]
# ---
# *Executed at: 2026-03-30T14:12:54.084542*

# %%
import matplotlib.pyplot as pltimport numpy as np# 设置中文字体plt.rcParams['font.sans-serif'] = ['Arial Unicode MS', 'SimHei', 'DejaVu Sans']plt.rcParams['axes.unicode_minus'] = False# 生成数据x = np.arange(1, 11)y1 = np.random.randint(20, 100, 10)y2 = np.random.randint(20, 100, 10)# 创建图表plt.figure(figsize=(10, 6))# 绘制两条折线plt.plot(x, y1, marker='o', linewidth=2, label='产品线 A', color='#3498db')plt.plot(x, y2, marker='s', linewidth=2, label='产品线 B', color='#e74c3c')# 填充区域plt.fill_between(x, y1, alpha=0.2, color='#3498db')plt.fill_between(x, y2, alpha=0.2, color='#e74c3c')# 添加标题和标签plt.title('月度销售数据对比', fontsize=16, fontweight='bold')plt.xlabel('月份', fontsize=12)plt.ylabel('销售额（万元）', fontsize=12)# 显示数值标签for i, (v1, v2) in enumerate(zip(y1, y2)):    plt.annotate(str(v1), (x[i], y1[i]), textcoords="offset points", xytext=(0,10), ha='center', fontsize=9)    plt.annotate(str(v2), (x[i], y2[i]), textcoords="offset points", xytext=(0,-15), ha='center', fontsize=9)# 图例和网格plt.legend(loc='upper left')plt.grid(True, linestyle='--', alpha=0.7)plt.tight_layout()# 显示图表plt.show()print("✅ 折线图已生成！")
# Out:
# <plot: /Users/lianghaoyun/project/nanobot/workspace/notebooks/default/plot_0.png>
# ✅ 折线图已生成！📊 Generated 1 chart(s)  Chart 1: /Users/lianghaoyun/project/nanobot/workspace/notebooks/default/plot_0.png

# %% [markdown]
# ---
# *Executed at: 2026-03-30T14:20:38.156704*

# %%
import pandas as pdimport numpy as npimport matplotlib.pyplot as plt# 生成示例时间序列数据dates = pd.date_range(start='2024-01-01', periods=30, freq='D')values = np.cumsum(np.random.randn(30) * 10) + 100  # 随机游走数据df = pd.DataFrame({'date': dates, 'value': values})# 绘制折线图plt.figure(figsize=(12, 6))plt.plot(df['date'], df['value'], marker='o', linestyle='-', linewidth=2, markersize=4, color='#2E86AB')plt.title('Time Series Line Chart', fontsize=16, fontweight='bold')plt.xlabel('Date', fontsize=12)plt.ylabel('Value', fontsize=12)# 旋转x轴日期标签plt.xticks(rotation=45)# 添加网格线plt.grid(True, linestyle='--', alpha=0.7)# 调整布局plt.tight_layout()plt.show()print(f"数据点数量: {len(df)}")print(f"时间范围: {df['date'].min().date()} 至 {df['date'].max().date()}")
# Out:
# (no output)

# %% [markdown]
# ---
# *Executed at: 2026-03-30T14:33:24.943035*
