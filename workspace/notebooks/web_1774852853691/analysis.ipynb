# %%
import matplotlib.pyplot as pltimport numpy as np# 创建示例数据x = np.linspace(0, 10, 50)y1 = np.sin(x)y2 = np.cos(x)# 创建折线图plt.figure(figsize=(10, 6))plt.plot(x, y1, label='sin(x)', linewidth=2, color='#3498db')plt.plot(x, y2, label='cos(x)', linewidth=2, color='#e74c3c', linestyle='--')plt.title('三角函数折线图示例', fontsize=16, fontweight='bold')plt.xlabel('X 轴', fontsize=12)plt.ylabel('Y 轴', fontsize=12)plt.legend(loc='upper right', fontsize=11)plt.grid(True, alpha=0.3, linestyle='--')plt.tight_layout()plt.show()  # 触发图表捕获并展示
# Out:
# <plot: plot_000.png>
# ...

# %% [markdown]
# ---
# *Executed at: 2026-03-30T14:41:57.854029*

# %%
import matplotlib.pyplot as pltimport numpy as np# Create sample datax = np.linspace(0, 10, 50)y1 = np.sin(x)y2 = np.cos(x)y3 = np.sin(x) * np.exp(-x/5)# Create line chartplt.figure(figsize=(12, 6))plt.plot(x, y1, label='sin(x)', linewidth=2.5, color='#3498db', marker='o', markersize=4, markevery=5)plt.plot(x, y2, label='cos(x)', linewidth=2.5, color='#e74c3c', linestyle='--', marker='s', markersize=4, markevery=5)plt.plot(x, y3, label='sin(x)·exp(-x/5)', linewidth=2.5, color='#2ecc71', linestyle='-.', marker='^', markersize=4, markevery=5)plt.title('Trigonometric Functions Comparison', fontsize=16, fontweight='bold', pad=15)plt.xlabel('X values (radians)', fontsize=13)plt.ylabel('Y values', fontsize=13)plt.legend(loc='upper right', fontsize=11, framealpha=0.9)plt.grid(True, alpha=0.3, linestyle='--', linewidth=0.8)plt.axhline(y=0, color='black', linestyle='-', linewidth=0.5)plt.axvline(x=0, color='black', linestyle='-', linewidth=0.5)plt.xlim(-0.5, 10.5)plt.ylim(-1.5, 1.5)plt.tight_layout()plt.show()
# Out:
# <plot: plot_000.png>
# <plot: plot_001.png>
# [PLOT_SAVED] plot_001.png

# %% [markdown]
# ---
# *Executed at: 2026-03-30T14:42:12.623346*
