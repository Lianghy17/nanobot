# %%
import matplotlib.pyplot as pltimport numpy as np# 设置中文字体plt.rcParams['font.sans-serif'] = ['Arial Unicode MS', 'SimHei', 'DejaVu Sans']plt.rcParams['axes.unicode_minus'] = False# 生成数据x = np.linspace(0, 10, 50)y1 = np.sin(x) * 10 + 50  # 正弦曲线y2 = np.cos(x) * 8 + 50   # 余弦曲线y3 = np.random.normal(50, 5, 50)  # 随机数据# 创建图表plt.figure(figsize=(12, 6))# 绘制多条折线plt.plot(x, y1, 'b-', linewidth=2, label='产品 A 销量', marker='o', markersize=4)plt.plot(x, y2, 'r--', linewidth=2, label='产品 B 销量', marker='s', markersize=4)plt.plot(x, y3, 'g:', linewidth=2, label='产品 C 销量', marker='^', markersize=4)# 添加标题和标签plt.title('月度销售趋势图', fontsize=16, fontweight='bold')plt.xlabel('月份', fontsize=12)plt.ylabel('销量 (万件)', fontsize=12)# 添加图例plt.legend(loc='upper right', fontsize=10)# 添加网格plt.grid(True, linestyle='--', alpha=0.7)# 设置背景色plt.gca().set_facecolor('#f8f9fa')plt.tight_layout()plt.show()
# Out:
# <plot: plot_000.png>
# [PLOT_SAVED] plot_000.png

# %% [markdown]
# ---
# *Executed at: 2026-03-30T14:49:41.664501*
