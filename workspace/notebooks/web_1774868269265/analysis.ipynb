# %%
import matplotlib.pyplot as pltimport numpy as np# 生成示例数据x = np.arange(1, 11)y = np.random.randint(10, 100, size=10)# 创建折线图plt.figure(figsize=(10, 6))plt.plot(x, y, marker='o', linewidth=2, markersize=8, color='#2196F3')plt.title('折线图示例', fontsize=16, fontweight='bold')plt.xlabel('X 轴', fontsize=12)plt.ylabel('Y 轴', fontsize=12)plt.grid(True, linestyle='--', alpha=0.7)plt.xticks(x)# 在每个点上添加数值标签for i, v in enumerate(y):    plt.text(x[i], v + 2, str(v), ha='center', fontsize=10)plt.tight_layout()plt.show()
# Out:
# <plot: plot_000.png>
# ...

# %% [markdown]
# ---
# *Executed at: 2026-03-30T18:57:58.799903*

# %%
import matplotlib.pyplot as pltimport numpy as np# Generate sample datanp.random.seed(42)x = np.arange(1, 11)y = np.cumsum(np.random.randn(10) * 10) + 50# Create line chartplt.figure(figsize=(10, 6))plt.plot(x, y, marker='o', linewidth=2.5, markersize=10, color='#2196F3', markerfacecolor='#FF5722', markeredgewidth=2)plt.title('Sample Line Chart', fontsize=16, fontweight='bold')plt.xlabel('Time Period', fontsize=12)plt.ylabel('Value', fontsize=12)plt.grid(True, linestyle='--', alpha=0.6)plt.xticks(x)# Add value labels on each pointfor i, v in enumerate(y):    plt.text(x[i], v + 1.5, f'{v:.1f}', ha='center', fontsize=10, fontweight='bold')plt.tight_layout()plt.show()
# Out:
# <plot: plot_000.png>
# <plot: plot_001.png>
# [PLOT_SAVED] plot_001.png

# %% [markdown]
# ---
# *Executed at: 2026-03-30T18:58:07.280368*
